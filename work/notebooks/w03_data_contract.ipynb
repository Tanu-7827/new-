# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\tanis\new-\work\notebooks

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
'''
### 1. Unit of analysis + time window

- One row represents one content page (content_id).
- The analysis uses historical search and engagement data.
- The prediction is based on a 90-day historical window.
- The unit of analysis is page-level.
- Future information is not used.'''
# Out:
# '\n### 1. Unit of analysis + time window\n\n- One row represents one content page (content_id).\n- The analysis uses historical search and engagement data.\n- The prediction is based on a 90-day historical window.\n- The unit of analysis is page-level.\n- Future information is not used.'

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
'''
### 2. Fields: feature / label / context / excluded

**Features**
- search_volume
- competition
- cpc
- word_count
- char_count
- impressions_90d
- clicks_90d
- sessions_90d

**Label**
- baseline_score

**Context**
- client_id
- content_type
- main_intent
- provider_used
- model_used

**Excluded**
- content_id (identifier only)
- reason_code (generated after scoring)
- Future outcome columns (to avoid data leakage)'''
# Out:
# '\n### 2. Fields: feature / label / context / excluded\n\n**Features**\n- search_volume\n- competition\n- cpc\n- word_count\n- char_count\n- impressions_90d\n- clicks_90d\n- sessions_90d\n\n**Label**\n- baseline_score\n\n**Context**\n- client_id\n- content_type\n- main_intent\n- provider_used\n- model_used\n\n**Excluded**\n- content_id (identifier only)\n- reason_code (generated after scoring)\n- Future outcome columns (to avoid data leakage)'

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Unique content_id:", df["content_id"].nunique())

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Rows: 30000
# Columns: 44
# Unique content_id: 30000
#
# Missing values:
# content_id                    0
# client_id                     0
# search_volume              2468
# competition                2468
# competition_level          2610
# cpc                        2468
# content_type                  0
# main_intent                2374
# word_count                 7699
# char_count                 7699
# provider_used             21438
# model_used                 5733
# impressions_90d               0
# clicks_90d                    0
# pageviews_90d                 0
# sessions_90d                  0
# users_90d                     0
# engaged_sessions_90d          0
# ai_sessions_90d               0
# scroll_events_90d             0
# days_with_impressions         0
# days_with_sessions            0
# impressions_last_30d          0
# clicks_last_30d               0
# sessions_last_30d             0
# impressions_prev_30d          0
# clicks_prev_30d               0
# ...

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
'''
### Data Limits

- The dataset contains only historical data.
- It cannot predict future events with certainty.
- Some fields may contain missing values.
- Results may be affected by seasonal traffic changes.
- The data should not be used with future information to avoid leakage.'''
# Out:
# '\n### Data Limits\n\n- The dataset contains only historical data.\n- It cannot predict future events with certainty.\n- Some fields may contain missing values.\n- Results may be affected by seasonal traffic changes.\n- The data should not be used with future information to avoid leakage.'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
