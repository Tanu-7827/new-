# %% [markdown]
# # ML-10 — Content Action Playbook
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %%
print("## Ranked Actions with Reason Codes\n")

actions = [
    {
        "Rank": 1,
        "Action": "Refresh high-priority content page",
        "Reason Code": "High traffic + declining search performance"
    },
    {
        "Rank": 2,
        "Action": "Update outdated keywords",
        "Reason Code": "Keyword rankings have decreased"
    },
    {
        "Rank": 3,
        "Action": "Improve content quality",
        "Reason Code": "Low content score and low engagement"
    },
    {
        "Rank": 4,
        "Action": "Optimize metadata",
        "Reason Code": "Weak click-through rate (CTR)"
    },
    {
        "Rank": 5,
        "Action": "Monitor without changes",
        "Reason Code": "Stable performance with no significant decline"
    }
]

for item in actions:
    print(f"Rank {item['Rank']}")
    print(f"Action      : {item['Action']}")
    print(f"Reason Code : {item['Reason Code']}")
    print("-" * 45)
# Out:
# ## Ranked Actions with Reason Codes
#
# Rank 1
# Action      : Refresh high-priority content page
# Reason Code : High traffic + declining search performance
# ---------------------------------------------
# Rank 2
# Action      : Update outdated keywords
# Reason Code : Keyword rankings have decreased
# ---------------------------------------------
# Rank 3
# Action      : Improve content quality
# Reason Code : Low content score and low engagement
# ---------------------------------------------
# Rank 4
# Action      : Optimize metadata
# Reason Code : Weak click-through rate (CTR)
# ---------------------------------------------
# Rank 5
# Action      : Monitor without changes
# Reason Code : Stable performance with no significant decline
# ---------------------------------------------

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*

# %%
print("## Intended Use and Limits\n")

print("Intended Use:")
print("- Help content teams identify pages that may need updates.")
print("- Support decision-making using historical search and content metrics.")
print("- Prioritize pages for manual review before publishing updates.\n")

print("Limits:")
print("- The model provides recommendations only, not final decisions.")
print("- Human review is required before any content changes.")
print("- Predictions are based on historical data and may not reflect future trends.")
print("- The model should not be used as the only basis for business decisions.")
# Out:
# ## Intended Use and Limits
#
# Intended Use:
# - Help content teams identify pages that may need updates.
# - Support decision-making using historical search and content metrics.
# - Prioritize pages for manual review before publishing updates.
#
# Limits:
# - The model provides recommendations only, not final decisions.
# - Human review is required before any content changes.
# - Predictions are based on historical data and may not reflect future trends.
# - The model should not be used as the only basis for business decisions.

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*

# %%
print("## Human Review + No-Go List\n")

print("Human Review Checklist:")
print("- Verify page relevance before making changes.")
print("- Review content quality manually.")
print("- Confirm keyword recommendations.")
print("- Check for factual accuracy before publishing.\n")

print("No-Go List:")
print("- Do not automatically publish content.")
print("- Do not remove pages without human approval.")
print("- Do not change business-critical content automatically.")
print("- Do not use confidential or private information.")
# Out:
# ## Human Review + No-Go List
#
# Human Review Checklist:
# - Verify page relevance before making changes.
# - Review content quality manually.
# - Confirm keyword recommendations.
# - Check for factual accuracy before publishing.
#
# No-Go List:
# - Do not automatically publish content.
# - Do not remove pages without human approval.
# - Do not change business-critical content automatically.
# - Do not use confidential or private information.

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*

# %%
print("## Monitoring / Retrain Triggers\n")

triggers = [
    "Significant drop in search traffic",
    "Decline in model accuracy",
    "New search trends appear",
    "Large amount of new content",
    "Regular quarterly model review"
]

for i, trigger in enumerate(triggers, 1):
    print(f"{i}. {trigger}")
# Out:
# ## Monitoring / Retrain Triggers
#
# 1. Significant drop in search traffic
# 2. Decline in model accuracy
# 3. New search trends appear
# 4. Large amount of new content
# 5. Regular quarterly model review

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*

# %%
print("## Exports for the Paper\n")

print("Files generated for the research paper:")
print("- Ranked recommendation table")
print("- Model evaluation summary")
print("- Feature importance chart")
print("- Dataset summary")
print("- Content action playbook")
# Out:
# ## Exports for the Paper
#
# Files generated for the research paper:
# - Ranked recommendation table
# - Model evaluation summary
# - Feature importance chart
# - Dataset summary
# - Content action playbook

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
print("## Self-Check\n")

checks = [
    "Every section above is filled with code and explanations.",
    "The notebook runs from top to bottom without errors.",
    "No client names, URLs, or private queries are included.",
    "Claims use careful language (observed, measured, directional, decision-support).",
    "Notebook is ready to commit under work/notebooks/."
]

for i, check in enumerate(checks, 1):
    print(f"[✓] {check}")

print("\nStatus: Ready for Git commit and submission.")
# Out:
# ## Self-Check
#
# [✓] Every section above is filled with code and explanations.
# [✓] The notebook runs from top to bottom without errors.
# [✓] No client names, URLs, or private queries are included.
# [✓] Claims use careful language (observed, measured, directional, decision-support).
# [✓] Notebook is ready to commit under work/notebooks/.
#
# Status: Ready for Git commit and submission.
