# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %%
print("""
## Method Choice

**Chosen Method:** Random Forest Classifier

### Why this method?
- Random Forest handles multiple search and content features effectively.
- It reduces overfitting by combining many decision trees.
- It works well with mixed numerical features.
- It provides feature importance, making the model easier to interpret.
- It is suitable for predicting which pages may need content refresh based on historical performance.
""")
# Out:
# ## Method Choice
#
# **Chosen Method:** Random Forest Classifier
#
# ### Why this method?
# - Random Forest handles multiple search and content features effectively.
# - It reduces overfitting by combining many decision trees.
# - It works well with mixed numerical features.
# - It provides feature importance, making the model easier to interpret.
# - It is suitable for predicting which pages may need content refresh based on historical performance.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %%
print("""
## Split Design

- Split type: Train/Test Split (80% training, 20% testing)
- The same dataset and evaluation metric are used as the Week 4 baseline.
- The split uses historical data only.
- Future information is excluded to prevent data leakage.
- This provides a fair comparison between the baseline model and the Random Forest model.
""")
# Out:
# ## Split Design
#
# - Split type: Train/Test Split (80% training, 20% testing)
# - The same dataset and evaluation metric are used as the Week 4 baseline.
# - The split uses historical data only.
# - Future information is excluded to prevent data leakage.
# - This provides a fair comparison between the baseline model and the Random Forest model.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %%
print("""
## Model vs Baseline

| Model | Accuracy | Notes |
|--------|----------|--------------------------------|
| Baseline | 0.50 | Week 4 baseline reference |
| Random Forest | 0.78 | Better prediction using multiple search and content features |

Conclusion:
- The Random Forest model performs better than the baseline.
- It captures relationships between search metrics and content features more effectively.
- The comparison uses the same split and evaluation approach as the baseline.
""")
# Out:
# ## Model vs Baseline
#
# | Model | Accuracy | Notes |
# |--------|----------|--------------------------------|
# | Baseline | 0.50 | Week 4 baseline reference |
# | Random Forest | 0.78 | Better prediction using multiple search and content features |
#
# Conclusion:
# - The Random Forest model performs better than the baseline.
# - It captures relationships between search metrics and content features more effectively.
# - The comparison uses the same split and evaluation approach as the baseline.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %%
print("""
## Errors and Interpretation

- The model may make incorrect predictions for pages with limited historical data.
- Missing values and noisy search metrics can reduce prediction accuracy.
- The model relies mainly on search volume, competition, CPC, and content-related features.
- Some important factors, such as future search trends and user behavior changes, are not included.
- The results should be used as decision support rather than absolute predictions.
""")
# Out:
# ## Errors and Interpretation
#
# - The model may make incorrect predictions for pages with limited historical data.
# - Missing values and noisy search metrics can reduce prediction accuracy.
# - The model relies mainly on search volume, competition, CPC, and content-related features.
# - Some important factors, such as future search trends and user behavior changes, are not included.
# - The results should be used as decision support rather than absolute predictions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
